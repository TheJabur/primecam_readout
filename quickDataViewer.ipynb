# %% [markdown]
# # Quick Data Viewer Notebook

# %%
import os
import glob
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal

# %%
# list of files in tmp/ sorted by creation time
tmpfnames = sorted(glob.iglob(os.path.join(os.getcwd()+'/tmp/', '*')), 
                   key=os.path.getctime, reverse=True) 

# latest file
fname = tmpfnames[0]

## PRINT DATE

# assume numpy array and load
dat = np.load(fname, allow_pickle=True)
dat
# Out:
# (array([ -192.,  -355., 19782., ...,   492.,  -238.,  -262.]),
#  array([  -351.,    156., 102658., ...,   -323.,   -212.,   -225.]))

# %%
# plt.plot(np.abs(dat[0] + 1j*dat[1])[:967])
plt.plot(np.abs(dat[0] + 1j*dat[1])[700:800])
plt.show()

# %%
# f,s21 = dat

# %%
# plt.plot(np.real(f), np.abs(s21))
# plt.show()

# %%
plt.plot((dat[0][:1024])**2 + (dat[1][:1024])**2)
plt.show()
# Out:
# /opt/anaconda3/envs/py38/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
# # visualize data
# plt.imshow(dat)
# plt.colorbar()
# plt.show()

# %%
scipy.signal.find_peaks(-np.abs(s21), prominence=1e5)[0]
# Out:
# array([ 57012, 121072, 184641, 309740, 373729, 437520])
