# %% [markdown]
# # Quick Data Viewer Notebook

# %%
import os
import glob
import numpy as np
import matplotlib.pyplot as plt

# %%
# list of files in tmp/ sorted by creation time
tmpfnames = sorted(glob.iglob(os.path.join(os.getcwd()+'/tmp/', '*')), 
                   key=os.path.getctime, reverse=True) 

# latest file
fname = tmpfnames[0]

## PRINT DATE

# assume numpy array and load
dat = np.load(fname, allow_pickle=True)
dat
# Out:
# (array([-2455., -2185.,  2550., ..., -2340., -2530., -2574.]),
#  array([ -794., -1364.,   421., ...,  1086.,   487.,  -154.]))

# %%
plt.plot(dat[0][:100])
plt.show()

# %%
# visualize data
plt.imshow(dat)
plt.colorbar()
plt.show()
